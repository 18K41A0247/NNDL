# %% [markdown]
# <a href="https://colab.research.google.com/github/18K41A0247/NNDL/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Find the global minimum point and value for the function f(x)=x^2+y^2+10

# %% [markdown]
# * Manual calculation for two iterations

# %% [markdown]
# ![New doc 20-Mar-2021 8.29 PM-1(2).jpg](data:image/jpeg;base64,...)![New doc 20-Mar-2021 8.29 PM-1(3).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# *   Optimal solution using python programming

# %%
from sympy import *
x=symbols('x')
y=symbols('y')
f=x**2+y**2+10
u=diff(f,x) 
v=diff(f,y) 
print("df/dx=",u)
print("df/dy=",v,"\n")
X=-1
Y=1
itr=1 
n=0.1 
epoch=2
while (itr <= epoch) :
   x1=u.subs(x,X)
   y1=v.subs(y,Y)
   print(f"differentiation of f({X}) =",x1)
   print(f"differentiation of f({Y}) =",y1)
   deltax=-n*x1
   deltay=-n*y1
   print("delta of x =",deltax)
   print("delta of y =",deltay)
   newx = X + deltax
   newy = Y + deltay
   print("new x =",newx)
   print("new y =",newy)
   itr= itr + 1
   X=newx
   Y=newy
   print(' ')
print("final x value =",X)
print("final y value =",Y)
print("Minimum value of f(x) is",f.subs([(x,X),(y,Y)]))
# Out:
# df/dx= 2*x
# df/dy= 2*y
#
# differentiation of f(-1) = -2
# differentiation of f(1) = 2
# delta of x = 0.200000000000000
# delta of y = -0.200000000000000
# new x = -0.800000000000000
# new y = 0.800000000000000
#
# differentiation of f(-0.800000000000000) = -1.60000000000000
# differentiation of f(0.800000000000000) = 1.60000000000000
# delta of x = 0.160000000000000
# delta of y = -0.160000000000000
# new x = -0.640000000000000
# new y = 0.640000000000000
#
# final x value = -0.640000000000000
# final y value = 0.640000000000000
# Minimum value of f(x) is 10.8192000000000
